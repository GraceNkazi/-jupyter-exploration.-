# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceNkazi/-ITAI-1371-ML-Labs-/blob/main/ITAI_1371_ML_Labs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade matplotlib matplotlib-inline
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 64.6 MB/s eta 0:00:00

# %%
import matplotlib.pyplot as plt

# Now your existing code will work:
plt.figure(figsize=(10, 6))
# ... the rest of your plotting code

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
print("all libraries imported successfully!")
# Out:
# all libraries imported successfully!

# %%
print(f"pandas version: {pd.__version__}")
# Out:
# pandas version: 2.2.2

# %%
print(f"numpy version: {np.__version__}")
# Out:
# numpy version: 2.0.2

# %%
# Load the data
iris = datasets.load_iris()
print("data loaded succefully!")
# Out:
# data loaded succefully!

# %%
print(f"Dataset shape: {iris.data.shape}")
print(f"Features: {iris.feature_names}")
print(f"Target names: {iris.target_names}")
# Out:
# Dataset shape: (150, 4)
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

#Display first few rows
print("First few rows of the dataset:")
print(df.head())

print("\nDataset information:")
print(df.info())
# Out:
# First few rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...

# %%
# Create a simple scatter plot
plt.figure(figsize=(10, 6))

# plot sepal lenth vs sepal width, colored by species
species_colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}

for species in df['species'].unique():
    species_data = df[df['species'] == species]
    plt.scatter(species_data['sepal length (cm)'],
                species_data['sepal width (cm)'],
                c=species_colors[species],
                label=species,
                alpha=0.7)

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Sepal Width by Species')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(" Congratulations! you've created your first data visualization!")

# %%
# Create a simple scatter plot
plt.figure(figsize=(10, 6))

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# 1. Load the raw data
iris = load_iris()

# 2. Create the 'df' variable that was missing
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = [iris.target_names[i] for i in iris.target]

# 3. Now your plotting code will work
plt.figure(figsize=(10, 6))
species_colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}

for species in df['species'].unique():
    species_data = df[df['species'] == species]
    plt.scatter(species_data['sepal length (cm)'],
                species_data['sepal width (cm)'],
                c=species_colors[species],
                label=species)

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.show()

# %%
# Basic statistical analysis
print("Basic Statistics for Iris Dataset:")
print("=" * 40)

# Calculate mean values for each species
species_means = df.groupby('species').mean()
print("\nMean values by species:")
print(species_means)

# Count samples per species
species_counts = df['species'].value_counts()
print("\nSamples per species:")
print(species_counts)
# Out:
# Basic Statistics for Iris Dataset:
# ...
#
# Mean values by species:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
#
# Samples per species:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
